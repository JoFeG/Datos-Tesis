# %%
import pandas as pd
df_grupos = pd.read_csv('./data/mrsat_grupos.csv')
df = pd.read_csv('./data/mrsat_hist.csv', converters = {'AgenteCausal1':str, 'CelMl1':str, 'AgenteCausal2':str, 'AgenteCausal3':str})

# %%
df
# Out:
#             ID   Folio  CodigoAnalisis     DescripcionAnalisis  Resultado
# 0            1  601277               5         RED CUALITATIVA        2.0  \
# 1            2  601277               6  INTEGRADA CUANTITATIVA        0.0
# 2            3  601278               5         RED CUALITATIVA        2.0
# 3            4  601278               6  INTEGRADA CUANTITATIVA        0.0
# 4            5  601279               1                     VPM        0.0
# ...        ...     ...             ...                     ...        ...
# 177579  194121  650801               6  INTEGRADA CUANTITATIVA        0.0
# 177580  194122  650984               5         RED CUALITATIVA        0.0
# 177581  194123  650984               6  INTEGRADA CUANTITATIVA        0.0
# 177582  194124  650985               1                     VPM       30.0
# 177583  194125  650417              20               E. COLI B       20.0
#
#         CodigoArea      DescripcionArea  CodigoCentro
# ...
